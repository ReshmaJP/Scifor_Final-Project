# %% [markdown]
# # Traffic Forecasting - Time Series using Neural Network

# %% [markdown]
# **About the data**
#
# This dataset is a collection of numbers of vehicles at four junctions at an hourly frequency.
# The CSV file provides four features:
#
# * DateTime
# * Junctions
# * Vehicles
# * ID
#
# The sensors on each of these junctions were collecting data at different times, hence the traffic data from different time periods. Some of the junctions have provided limited or sparse data.

# %% [markdown]
# # Importing Libraries

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
import os
from keras.models import load_model
from tensorflow.keras.models import load_model
from tensorflow.keras.models import save_model
import pickle

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading Data

# %%
#Loading Data
data = pd.read_csv("traffic.csv")
data.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  object
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
#  3   ID        48120 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# # Checking Missing values

# %%
data.isnull().sum()
# Out:
# DateTime    0
# Junction    0
# Vehicles    0
# ID          0
# dtype: int64

# %% [markdown]
# # Data Exploration
# * Pharsing dates
# * Ploting timeseris
# * Feature engineering for EDA

# %%
data["DateTime"]= pd.to_datetime(data["DateTime"])
data = data.drop(["ID"], axis=1) #dropping IDs
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  datetime64[ns]
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 1.1 MB

# %%
#df to be used for EDA
df=data.copy() 
#Let's plot the Timeseries
#colors = [ "#FFD4DB","#BBE7FE","#D3B5E5","#dfe2b6"]
#colors = ["#FF5733", "#33FF57", "#3357FF", "#FF33E6"]
colors = ["#A52A2A", "#FFFF00", "#3357FF", "#00FF00"]
#colors = 'colorblind'
plt.figure(figsize=(20,4)) #facecolor="white")
Time_series=sns.lineplot(x=df['DateTime'],y="Vehicles",data=df, hue="Junction", palette=colors)
Time_series.set_title("Traffic On Junctions Over Years")
Time_series.set_ylabel("Number of Vehicles")
Time_series.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# **Noticeable information in the above plot:**
#
# * It can be seen here that the first junction is visibly having an upward trend.
# * The data for the fourth junction is sparse starting only after 2017
# * Seasonality is not evident from the above plot, So we must explore datetime composition to figure out more about it.

# %% [markdown]
# # Feature Engineering
#
# In this step, I am creating a few new features out of DateTime.
# Namely:
# * Year
# * Month
# * Date in the given month
# * Days of week
# * Hour

# %%
#Exploring more features 
df["Year"]= df['DateTime'].dt.year
df["Month"]= df['DateTime'].dt.month
df["Date_no"]= df['DateTime'].dt.day
df["Hour"]= df['DateTime'].dt.hour
df["Day"]= df.DateTime.dt.strftime("%A")
df.head()
# Out:
#              DateTime  Junction  Vehicles  Year  Month  Date_no  Hour     Day
# 0 2015-11-01 00:00:00         1        15  2015     11        1     0  Sunday
# 1 2015-11-01 01:00:00         1        13  2015     11        1     1  Sunday
# 2 2015-11-01 02:00:00         1        10  2015     11        1     2  Sunday
# 3 2015-11-01 03:00:00         1         7  2015     11        1     3  Sunday
# 4 2015-11-01 04:00:00         1         9  2015     11        1     4  Sunday

# %% [markdown]
# # Exploratory Data Analysis
#
# Plotting the newly created features

# %%
#Let's plot the Timeseries
new_features = [ "Year","Month", "Date_no", "Hour", "Day"]
colors = ["#A52A2A", "#FFFF00", "#3357FF", "#00FF00"]
for i in new_features:
    plt.figure(figsize=(10,2))#,facecolor="#627D78")
    ax=sns.lineplot(x=df[i],y="Vehicles",data=df, hue="Junction", palette=colors )
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# **From the above plot following things can be concluded:**
#
#
# * Yearly, there has been an upward trend for all junctions except for the fourth junction. As we already established above that the fourth junction has limited data and that don't span over a year.
#
# * We can see that there is an influx in the first and second junctions around June. I presume this may be due to summer break and activities around the same.
#
# * Monthly, throughout all the dates there is a good consistency in data.
#
# * For a day, we can see that are peaks during morning and evening times and a decline during night hours. This is as per expectation.
#
# * For weekly patterns, Sundays enjoy smoother traffic as there are lesser vehicles on roads. Whereas Monday to Friday the traffic is steady.

# %%
plt.figure(figsize=(12,5),facecolor="#627D78")
count = sns.countplot(data=df, x =df["Year"], hue="Junction", palette=colors)
count.set_title("Count Of Traffic On Junctions Over Years")
count.set_ylabel("Number of Vehicles")
count.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# The count plot shows that there is an increase in the number of vehicles between 2015 and 2016. However, it is inconclusive to say the same about 2017 as we have limited data for 2017 ie till the 7th month.

# %%
corrmat = df.corr()
plt.subplots(figsize=(10,10),facecolor="#627D78")
sns.heatmap(corrmat,cmap= "Pastel2",annot=True,square=True, )
# Out:
# <Axes: >

# %% [markdown]
# The highest correlation is certainly with the preexisting feature.
#
# I will conclude my EDA with a pair plot. It's an interesting overall representation of any data.

# %%
sns.pairplot(data=df, hue= "Junction",palette=colors)

# %% [markdown]
# **Conclusions that I have come to draw after this EDA**
#
# * The span of data from all four junctions is not the same. Data provided for the fourth junction is limited to only 2017.
# * The yearly trend for Junctions one, two and three have diffrent slopes.
# * Junction number one has a more strong weekly seasonality in comparison to the other junctions.
#
# For the above-postulated reasons, I think that junctions must be transformed as per their individual needs.

# %% [markdown]
# # Data Transformation And Preprocessing

# %%
#Pivoting data fron junction 
df_J = data.pivot(columns="Junction", index="DateTime")
df_J.describe()
# Out:
#               Vehicles
# Junction             1             2             3            4
# count     14592.000000  14592.000000  14592.000000  4344.000000
# mean         45.052906     14.253221     13.694010     7.251611
# std          23.008345      7.401307     10.436005     3.521455
# min           5.000000      1.000000      1.000000     1.000000
# 25%          27.000000      9.000000      7.000000     5.000000
# 50%          40.000000     13.000000     11.000000     7.000000
# 75%          59.000000     17.000000     18.000000     9.000000
# max         156.000000     48.000000    180.000000    36.000000

# %%
df_J
# Out:
#                     Vehicles
# Junction                   1     2     3     4
# DateTime
# 2015-11-01 00:00:00     15.0   6.0   9.0   NaN
# 2015-11-01 01:00:00     13.0   6.0   7.0   NaN
# 2015-11-01 02:00:00     10.0   5.0   5.0   NaN
# 2015-11-01 03:00:00      7.0   6.0   1.0   NaN
# 2015-11-01 04:00:00      9.0   7.0   2.0   NaN
# ...                      ...   ...   ...   ...
# 2017-06-30 19:00:00    105.0  34.0  33.0  11.0
# 2017-06-30 20:00:00     96.0  35.0  31.0  30.0
# 2017-06-30 21:00:00     90.0  31.0  28.0  16.0
# 2017-06-30 22:00:00     84.0  29.0  26.0  22.0
# 2017-06-30 23:00:00     78.0  27.0  39.0  12.0
#
# [14592 rows x 4 columns]

# %%
df_J.columns
# Out:
# MultiIndex([('Vehicles', 1),
#             ('Vehicles', 2),
#             ('Vehicles', 3),
#             ('Vehicles', 4)],
#            names=[None, 'Junction'])

# %%
#Creating new sets
df_1 = df_J[[('Vehicles', 1)]]
df_2 = df_J[[('Vehicles', 2)]]
df_3 = df_J[[('Vehicles', 3)]]
df_4 = df_J[[('Vehicles', 4)]]
df_4 = df_4.dropna() #Junction 4 has limited data only for a few months

#Dropping level one in dfs's index as it is a multi index data frame
list_dfs = [df_1, df_2, df_3, df_4]
for i in list_dfs:
    i.columns= i.columns.droplevel(level=1)   

#Function to plot comparitive plots of dataframes
def Sub_Plots4(df_1, df_2,df_3,df_4,title):
    fig, axes = plt.subplots(4, 1, figsize=(15, 8), sharey=True)#,facecolor="white", 
    fig.suptitle(title)
    #J1
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[0])
    #pl_1=plt.ylabel()
    axes[0].set(ylabel ="Junction 1")
    #J2
    pl_2=sns.lineplot(ax=axes[1],data=df_2,color=colors[1])
    axes[1].set(ylabel ="Junction 2")
    #J3
    pl_3=sns.lineplot(ax=axes[2],data=df_3,color=colors[2])
    axes[2].set(ylabel ="Junction 3")
    #J4
    pl_4=sns.lineplot(ax=axes[3],data=df_4,color=colors[3])
    axes[3].set(ylabel ="Junction 4")
    
    
#Plotting the dataframe to check for stationarity
Sub_Plots4(df_1.Vehicles, df_2.Vehicles,df_3.Vehicles,df_4.Vehicles,"Dataframes Before Transformation")

# %% [markdown]
# A time series is stationary if it does not have a trend or seasonality. However, in the EDA, we saw a weekly seasonality and an upwards trend over the years. In the above plot, it is again established that Junctions one and two have an upward trend. If we limit the span we will be able to further see the weekly seasonality. I will be spairing that step at this point and moving on with the respective transforms on datasets.
#
# **Steps for Transforming:**
# * Normalizing
# * Differencing

# %%
# Normalize Function
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average) / stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

# Differencing Function
def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %% [markdown]
# In accordance with the above observations, Differencing to eliminate the seasonality should be performed as follows:
# * For Junction one, I will be taking a difference of weekly values.
# * For junction two, The difference of consecutive days is a better choice
# * For Junctions three and four, the difference of the hourly values will serve the purpose.

# %%
#Normalizing and Differencing to make the series stationary 
df_N1, av_J1, std_J1 = Normalize(df_1, "Vehicles")
Diff_1 = Difference(df_N1, col="Vehicles", interval=(24*7)) #taking a week's diffrence
df_N1 = df_N1[24*7:]
df_N1.columns = ["Norm"]
df_N1["Diff"]= Diff_1

df_N2, av_J2, std_J2 = Normalize(df_2, "Vehicles")
Diff_2 = Difference(df_N2, col="Vehicles", interval=(24)) #taking a day's diffrence
df_N2 = df_N2[24:]
df_N2.columns = ["Norm"]
df_N2["Diff"]= Diff_2

df_N3, av_J3, std_J3 = Normalize(df_3, "Vehicles")
Diff_3 = Difference(df_N3, col="Vehicles", interval=1) #taking an hour's diffrence
df_N3 = df_N3[1:]
df_N3.columns = ["Norm"]
df_N3["Diff"]= Diff_3

df_N4, av_J4, std_J4 = Normalize(df_4, "Vehicles")
Diff_4 = Difference(df_N4, col="Vehicles", interval=1) #taking an hour's diffrence
df_N4 = df_N4[1:]
df_N4.columns = ["Norm"]
df_N4["Diff"]= Diff_4

# %% [markdown]
# **Plots of Transformed Dataframe**

# %%
Sub_Plots4(df_N1.Diff, df_N2.Diff,df_N3.Diff,df_N4.Diff,"Dataframes After Transformation")

# %% [markdown]
# The plots above seem linear. To ensure they are Stationary I will be performing an Augmented Dickey-Fuller test.

# %%
#Stationary Check for the time series Augmented Dickey Fuller test
def Stationary_check(df):
    check = adfuller(df.dropna())
    print(f"ADF Statistic: {check[0]}")
    print(f"p-value: {check[1]}")
    print("Critical Values:")
    for key, value in check[4].items():
        print('\t%s: %.3f' % (key, value))
    if check[0] > check[4]["1%"]:
        print("Time Series is Non-Stationary")
    else:
        print("Time Series is Stationary") 
  

#Checking if the series is stationary

List_df_ND = [ df_N1["Diff"], df_N2["Diff"], df_N3["Diff"], df_N4["Diff"]] 
print("Checking the transformed series for stationarity:")
for i in List_df_ND:
    print("\n")
    Stationary_check(i)
# Out:
# Checking the transformed series for stationarity:
#
#
# ADF Statistic: -15.265303390415426
# p-value: 4.7985398763968885e-28
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -21.795891026940296
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -28.001759908832412
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -17.97909256305261
# p-value: 2.778787532594783e-30
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary

# %% [markdown]
# **Now that the data is stationary,  preprocessing the data for the neural net by:**
#
# * Splitting the test train sets
# * Assigning X as features and y as target
# * Reshaping data for neural net

# %%
#Differencing created some NA values as we took a weeks data into consideration while difrencing
df_J1 = df_N1["Diff"].dropna()
df_J1 = df_J1.to_frame()

df_J2 = df_N2["Diff"].dropna()
df_J2 = df_J2.to_frame()

df_J3 = df_N3["Diff"].dropna()
df_J3 = df_J3.to_frame()

df_J4 = df_N4["Diff"].dropna()
df_J4 = df_J4.to_frame()

#Splitting the dataset
def Split_data(df):
    training_size = int(len(df)*0.90)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len] 
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test
#Splitting the training and test datasets 
J1_train, J1_test = Split_data(df_J1)
J2_train, J2_test = Split_data(df_J2)
J3_train, J3_test = Split_data(df_J3)
J4_train, J4_test = Split_data(df_J4)

#Target and Feature
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

#fixing the shape of X_test and X_train
def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

#Assigning features and target 
X_trainJ1, y_trainJ1 = TnF(J1_train)
X_testJ1, y_testJ1 = TnF(J1_test)
X_trainJ1, X_testJ1 = FeatureFixShape(X_trainJ1, X_testJ1)

X_trainJ2, y_trainJ2 = TnF(J2_train)
X_testJ2, y_testJ2 = TnF(J2_test)
X_trainJ2, X_testJ2 = FeatureFixShape(X_trainJ2, X_testJ2)

X_trainJ3, y_trainJ3 = TnF(J3_train)
X_testJ3, y_testJ3 = TnF(J3_test)
X_trainJ3, X_testJ3 = FeatureFixShape(X_trainJ3, X_testJ3)

X_trainJ4, y_trainJ4 = TnF(J4_train)
X_testJ4, y_testJ4 = TnF(J4_test)
X_trainJ4, X_testJ4 = FeatureFixShape(X_trainJ4, X_testJ4)

# %%
print("Shape of y_train:", y_trainJ1.shape)
print("Shape of y_test:", y_testJ1.shape)
print("Shape of y_train:", y_trainJ2.shape)
print("Shape of y_test:", y_testJ2.shape)
print("Shape of y_train:", y_trainJ3.shape)
print("Shape of y_test:", y_testJ3.shape)
print("Shape of y_train:", y_trainJ4.shape)
print("Shape of y_test:", y_testJ4.shape)
print("Shape of X_train:", X_trainJ1.shape)
print("Shape of X_test:", X_testJ1.shape)
print("Shape of X_train:", X_trainJ2.shape)
print("Shape of X_test:", X_testJ2.shape)
print("Shape of X_train:", X_trainJ3.shape)
print("Shape of X_test:", X_testJ3.shape)
print("Shape of X_train:", X_trainJ4.shape)
print("Shape of X_test:", X_testJ4.shape)
# Out:
# Shape of y_train: (12949,)
# Shape of y_test: (1411,)
# Shape of y_train: (13079,)
# Shape of y_test: (1425,)
# Shape of y_train: (13099,)
# Shape of y_test: (1428,)
# Shape of y_train: (3876,)
# Shape of y_test: (403,)
# Shape of X_train: (12949, 32, 1)
# Shape of X_test: (1411, 32, 1)
# Shape of X_train: (13079, 32, 1)
# Shape of X_test: (1425, 32, 1)
# Shape of X_train: (13099, 32, 1)
# Shape of X_test: (1428, 32, 1)
# Shape of X_train: (3876, 32, 1)
# Shape of X_test: (403, 32, 1)

# %% [markdown]
# # Model Building

# %%
#Model for the prediction
#from tensorflow.keras.optimizers import SGD
#from tensorflow.keras import callbacks

def lr_schedule(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * 0.9
    
def GRU_model(X_Train, y_Train, X_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True) 
    #callback delta 0.01 may interrupt the learning, could eliminate this step, but meh!
    
    #The GRU model 
    model = Sequential()
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    #model.add(GRU(units=50, return_sequences=True,  input_shape=(X_Train.shape[1],1),activation='tanh'))
    #model.add(Dropout(0.2))
    model.add(GRU(units=50, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    #Compiling the model
    model.compile(optimizer=SGD(learning_rate=0.01),loss='mean_squared_error')
    model.fit(X_Train,y_Train, epochs=50, batch_size=150,callbacks=[early_stopping, callbacks.LearningRateScheduler(lr_schedule)])
    pred_GRU= model.predict(X_Test)
    return pred_GRU

#To calculate the root mean squred error in predictions
def RMSE_Value(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

#To plot the comparitive plot of targets and predictions
def PredictionsPlot(test,predicted,m):
    plt.figure(figsize=(12,5),facecolor="#627D78")
    plt.plot(test, color=colors[m],label="True Value",alpha=0.5 )
    plt.plot(predicted, color="#627D78",label="Predicted Values")
    plt.title("GRU Traffic Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %% [markdown]
# # Fitting The Model

# %% [markdown]
# **Fitting the first junction and plotting the predictions and testset**

# %%
# Predictions For First Junction
PredJ1 = GRU_model(X_trainJ1,y_trainJ1,X_testJ1)
RMSE_J1 = RMSE_Value(y_testJ1, PredJ1)
PredictionsPlot(y_testJ1, PredJ1, 0)

# Save the trained model for Junction 2
#with open("junction_1_model.pkl", "wb") as model_file:
    #pickle.dump(model_J1, model_file)

# Save RMSE values
#np.save("junction_1_rmse.npy", RMSE_J1)
# Save the test datasets
#np.save("junction_1_test_features.npy", X_testJ1)
# Out:
# WARNING:tensorflow:From C:\Users\SONY\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\SONY\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 87/87 [==============================] - ETA: 0s - loss: 0.0938WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 62s 490ms/step - loss: 0.0938 - lr: 0.0100
# Epoch 2/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0820WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 508ms/step - loss: 0.0820 - lr: 0.0100
# Epoch 3/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0737WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 501ms/step - loss: 0.0737 - lr: 0.0100
# Epoch 4/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0691WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 508ms/step - loss: 0.0691 - lr: 0.0100
# Epoch 5/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0677WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 499ms/step - loss: 0.0677 - lr: 0.0100
# Epoch 6/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0673WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 500ms/step - loss: 0.0673 - lr: 0.0100
# Epoch 7/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0671WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 509ms/step - loss: 0.0671 - lr: 0.0100
# Epoch 8/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0670WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 521ms/step - loss: 0.0670 - lr: 0.0100
# Epoch 9/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0668WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 512ms/step - loss: 0.0668 - lr: 0.0100
# Epoch 10/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0667WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 507ms/step - loss: 0.0667 - lr: 0.0100
# Epoch 11/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0667WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 507ms/step - loss: 0.0667 - lr: 0.0090
# Epoch 12/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0659WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 516ms/step - loss: 0.0659 - lr: 0.0081
# Epoch 13/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0656WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 512ms/step - loss: 0.0656 - lr: 0.0073
# Epoch 14/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0656WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 501ms/step - loss: 0.0656 - lr: 0.0066
# Epoch 15/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0659WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 494ms/step - loss: 0.0659 - lr: 0.0059
# Epoch 16/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0653WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 506ms/step - loss: 0.0653 - lr: 0.0053
# Epoch 17/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0652WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 494ms/step - loss: 0.0652 - lr: 0.0048
# Epoch 18/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0658WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 491ms/step - loss: 0.0658 - lr: 0.0043
# Epoch 19/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0651WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 503ms/step - loss: 0.0651 - lr: 0.0039
# Epoch 20/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0651WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 500ms/step - loss: 0.0651 - lr: 0.0035
# Epoch 21/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0653WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 494ms/step - loss: 0.0653 - lr: 0.0031
# Epoch 22/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0651WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 504ms/step - loss: 0.0651 - lr: 0.0028
# Epoch 23/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0650WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 498ms/step - loss: 0.0650 - lr: 0.0025
# Epoch 24/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0655WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 507ms/step - loss: 0.0655 - lr: 0.0023
# Epoch 25/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0650WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 47s 546ms/step - loss: 0.0650 - lr: 0.0021
# Epoch 26/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0653WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 525ms/step - loss: 0.0653 - lr: 0.0019
# Epoch 27/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0650WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 47s 536ms/step - loss: 0.0650 - lr: 0.0017
# Epoch 28/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0646WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 517ms/step - loss: 0.0646 - lr: 0.0015
# Epoch 29/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0646WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 503ms/step - loss: 0.0646 - lr: 0.0014
# Epoch 30/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0648WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 504ms/step - loss: 0.0648 - lr: 0.0012
# Epoch 31/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0644WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 502ms/step - loss: 0.0644 - lr: 0.0011
# Epoch 32/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0647WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 43s 498ms/step - loss: 0.0647 - lr: 9.8477e-04
# Epoch 33/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0646WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 502ms/step - loss: 0.0646 - lr: 8.8629e-04
# Epoch 34/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0647WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 532ms/step - loss: 0.0647 - lr: 7.9766e-04
# Epoch 35/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0647WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 529ms/step - loss: 0.0647 - lr: 7.1790e-04
# Epoch 36/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0647WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 513ms/step - loss: 0.0647 - lr: 6.4611e-04
# Epoch 37/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0641WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 500ms/step - loss: 0.0641 - lr: 5.8150e-04
# Epoch 38/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0645WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 531ms/step - loss: 0.0645 - lr: 5.2335e-04
# Epoch 39/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0646WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 525ms/step - loss: 0.0646 - lr: 4.7101e-04
# Epoch 40/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0648WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 530ms/step - loss: 0.0648 - lr: 4.2391e-04
# Epoch 41/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0644WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 517ms/step - loss: 0.0644 - lr: 3.8152e-04
# Epoch 42/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0643WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 504ms/step - loss: 0.0643 - lr: 3.4337e-04
# Epoch 43/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0642WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 521ms/step - loss: 0.0642 - lr: 3.0903e-04
# Epoch 44/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0650WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 520ms/step - loss: 0.0650 - lr: 2.7813e-04
# Epoch 45/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0644WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 516ms/step - loss: 0.0644 - lr: 2.5032e-04
# Epoch 46/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0646WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 513ms/step - loss: 0.0646 - lr: 2.2528e-04
# Epoch 47/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0647WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 46s 523ms/step - loss: 0.0647 - lr: 2.0276e-04
# Epoch 48/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0649WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 45s 512ms/step - loss: 0.0649 - lr: 1.8248e-04
# Epoch 49/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0648WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 502ms/step - loss: 0.0648 - lr: 1.6423e-04
# Epoch 50/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0646WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 508ms/step - loss: 0.0646 - lr: 1.4781e-04
# 45/45 [==============================] - 9s 62ms/step
# The root mean squared error is 0.3001512846493656.

# %% [markdown]
# **Fitting the second junction and plotting the predictions and testset**

# %%
# Predictions For Second Junction
PredJ2 = GRU_model(X_trainJ2, y_trainJ2, X_testJ2)
RMSE_J2 = RMSE_Value(y_testJ2, PredJ2)
PredictionsPlot(y_testJ2, PredJ2, 1)

# Save the trained model for Junction 2
#with open("junction_2_model.pkl", "wb") as model_file:
    #pickle.dump(model_J2, model_file)

# Save RMSE values
#np.save("junction_2_rmse.npy", RMSE_J2)
# Save the test datasets
#np.save("junction_2_test_features.npy", X_testJ2)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2875WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 69s 537ms/step - loss: 0.2875 - lr: 0.0100
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2376WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 54s 619ms/step - loss: 0.2376 - lr: 0.0100
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2218WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 53s 602ms/step - loss: 0.2218 - lr: 0.0100
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2188WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 49s 556ms/step - loss: 0.2188 - lr: 0.0100
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2168WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 45s 507ms/step - loss: 0.2168 - lr: 0.0100
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2141WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 44s 501ms/step - loss: 0.2141 - lr: 0.0100
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2122WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 44s 498ms/step - loss: 0.2122 - lr: 0.0100
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2113WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 490ms/step - loss: 0.2113 - lr: 0.0100
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2091WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 489ms/step - loss: 0.2091 - lr: 0.0100
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2078WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 45s 506ms/step - loss: 0.2078 - lr: 0.0100
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2071WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 44s 494ms/step - loss: 0.2071 - lr: 0.0090
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2049WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 490ms/step - loss: 0.2049 - lr: 0.0081
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2037WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 486ms/step - loss: 0.2037 - lr: 0.0073
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2024WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 486ms/step - loss: 0.2024 - lr: 0.0066
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2018WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 490ms/step - loss: 0.2018 - lr: 0.0059
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2015WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 489ms/step - loss: 0.2015 - lr: 0.0053
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 44s 496ms/step - loss: 0.2010 - lr: 0.0048
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2005WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 488ms/step - loss: 0.2005 - lr: 0.0043
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1998WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 492ms/step - loss: 0.1998 - lr: 0.0039
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1988WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 487ms/step - loss: 0.1988 - lr: 0.0035
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1989WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 486ms/step - loss: 0.1989 - lr: 0.0031
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1992WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 485ms/step - loss: 0.1992 - lr: 0.0028
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1985WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 486ms/step - loss: 0.1985 - lr: 0.0025
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1977WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 488ms/step - loss: 0.1977 - lr: 0.0023
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1975WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 44s 495ms/step - loss: 0.1975 - lr: 0.0021
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1984WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 45s 504ms/step - loss: 0.1984 - lr: 0.0019
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1981WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 44s 504ms/step - loss: 0.1981 - lr: 0.0017
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1970WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 45s 511ms/step - loss: 0.1970 - lr: 0.0015
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1973WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 478ms/step - loss: 0.1973 - lr: 0.0014
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1974WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 475ms/step - loss: 0.1974 - lr: 0.0012
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1983WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 44s 497ms/step - loss: 0.1983 - lr: 0.0011
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1976WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 475ms/step - loss: 0.1976 - lr: 9.8477e-04
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1959WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 474ms/step - loss: 0.1959 - lr: 8.8629e-04
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1986WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 476ms/step - loss: 0.1986 - lr: 7.9766e-04
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1965WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 475ms/step - loss: 0.1965 - lr: 7.1790e-04
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1964WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 475ms/step - loss: 0.1964 - lr: 6.4611e-04
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1968WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 485ms/step - loss: 0.1968 - lr: 5.8150e-04
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 477ms/step - loss: 0.1967 - lr: 5.2335e-04
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1969WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 482ms/step - loss: 0.1969 - lr: 4.7101e-04
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1971WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 475ms/step - loss: 0.1971 - lr: 4.2391e-04
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1971WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 475ms/step - loss: 0.1971 - lr: 3.8152e-04
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1967WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 479ms/step - loss: 0.1967 - lr: 3.4337e-04
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1966WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 473ms/step - loss: 0.1966 - lr: 3.0903e-04
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1968WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 475ms/step - loss: 0.1968 - lr: 2.7813e-04
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1964WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 474ms/step - loss: 0.1964 - lr: 2.5032e-04
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1964WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 477ms/step - loss: 0.1964 - lr: 2.2528e-04
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1978WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 477ms/step - loss: 0.1978 - lr: 2.0276e-04
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1965WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 472ms/step - loss: 0.1965 - lr: 1.8248e-04
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1965WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 478ms/step - loss: 0.1965 - lr: 1.6423e-04
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1973WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 478ms/step - loss: 0.1973 - lr: 1.4781e-04
# 45/45 [==============================] - 9s 62ms/step
# The root mean squared error is 0.6211304479095612.

# %% [markdown]
# **Fitting the third junction and plotting the predictions and testset**

# %%
# Predictions For Third Junction
PredJ3 = GRU_model(X_trainJ3, y_trainJ3, X_testJ3)
RMSE_J3 = RMSE_Value(y_testJ3, PredJ3)
PredictionsPlot(y_testJ3, PredJ3, 2)

# Save the trained model for Junction 3
#with open("junction_3_model.pkl", "wb") as model_file:
    #pickle.dump(model_J3, model_file)

# Save RMSE values
#np.save("junction_3_rmse.npy", RMSE_J3)
# Save the test datasets
#np.save("junction_3_test_features.npy", X_testJ3)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.3025WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 69s 482ms/step - loss: 0.3025 - lr: 0.0100
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.3005WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 490ms/step - loss: 0.3005 - lr: 0.0100
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2996WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 489ms/step - loss: 0.2996 - lr: 0.0100
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2981WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 45s 509ms/step - loss: 0.2981 - lr: 0.0100
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2963WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 45s 516ms/step - loss: 0.2963 - lr: 0.0100
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 492ms/step - loss: 0.2950 - lr: 0.0100
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2940WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 486ms/step - loss: 0.2940 - lr: 0.0100
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2926WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 487ms/step - loss: 0.2926 - lr: 0.0100
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2919WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 483ms/step - loss: 0.2919 - lr: 0.0100
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2911WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 483ms/step - loss: 0.2911 - lr: 0.0100
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2902WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 483ms/step - loss: 0.2902 - lr: 0.0090
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2891WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 483ms/step - loss: 0.2891 - lr: 0.0081
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 480ms/step - loss: 0.2886 - lr: 0.0073
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2887WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 483ms/step - loss: 0.2887 - lr: 0.0066
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2883WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 481ms/step - loss: 0.2883 - lr: 0.0059
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2876WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 479ms/step - loss: 0.2876 - lr: 0.0053
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 487ms/step - loss: 0.2882 - lr: 0.0048
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2884WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 482ms/step - loss: 0.2884 - lr: 0.0043
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2873WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 484ms/step - loss: 0.2873 - lr: 0.0039
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2874WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 481ms/step - loss: 0.2874 - lr: 0.0035
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2875WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 483ms/step - loss: 0.2875 - lr: 0.0031
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2874WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 476ms/step - loss: 0.2874 - lr: 0.0028
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 483ms/step - loss: 0.2868 - lr: 0.0025
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2872WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 476ms/step - loss: 0.2872 - lr: 0.0023
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2870WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 486ms/step - loss: 0.2870 - lr: 0.0021
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2863WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 485ms/step - loss: 0.2863 - lr: 0.0019
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2866WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 478ms/step - loss: 0.2866 - lr: 0.0017
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2865WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 481ms/step - loss: 0.2865 - lr: 0.0015
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2866WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 479ms/step - loss: 0.2866 - lr: 0.0014
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 479ms/step - loss: 0.2868 - lr: 0.0012
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 481ms/step - loss: 0.2868 - lr: 0.0011
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2866WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 482ms/step - loss: 0.2866 - lr: 9.8477e-04
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2863WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 488ms/step - loss: 0.2863 - lr: 8.8629e-04
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2860WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 487ms/step - loss: 0.2860 - lr: 7.9766e-04
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2867WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 488ms/step - loss: 0.2867 - lr: 7.1790e-04
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 483ms/step - loss: 0.2862 - lr: 6.4611e-04
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 487ms/step - loss: 0.2862 - lr: 5.8150e-04
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 485ms/step - loss: 0.2859 - lr: 5.2335e-04
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2864WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 486ms/step - loss: 0.2864 - lr: 4.7101e-04
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 485ms/step - loss: 0.2868 - lr: 4.2391e-04
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2863WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 484ms/step - loss: 0.2863 - lr: 3.8152e-04
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 486ms/step - loss: 0.2862 - lr: 3.4337e-04
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2863WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 486ms/step - loss: 0.2863 - lr: 3.0903e-04
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 487ms/step - loss: 0.2868 - lr: 2.7813e-04
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2867WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 485ms/step - loss: 0.2867 - lr: 2.5032e-04
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2860WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 486ms/step - loss: 0.2860 - lr: 2.2528e-04
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2864WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 488ms/step - loss: 0.2864 - lr: 2.0276e-04
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2858WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 487ms/step - loss: 0.2858 - lr: 1.8248e-04
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 491ms/step - loss: 0.2862 - lr: 1.6423e-04
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2865WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 485ms/step - loss: 0.2865 - lr: 1.4781e-04
# 45/45 [==============================] - 12s 64ms/step
# The root mean squared error is 0.6281028084694495.

# %% [markdown]
# **Fitting the fourth junction and plotting the predictions and testset**

# %%
# Predictions For Fourth Junction
PredJ4 = GRU_model(X_trainJ4, y_trainJ4, X_testJ4)
RMSE_J4 = RMSE_Value(y_testJ4, PredJ4)
PredictionsPlot(y_testJ4, PredJ4, 3)

# Save the trained model for Junction 4
#with open("junction_4_model.pkl", "wb") as model_file:
    #pickle.dump(model_J4, model_file)

# Save RMSE values
#np.save("junction_4_rmse.npy", RMSE_J4)
# Save the test datasets
#np.save("junction_4_test_features.npy", X_testJ4)
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6864WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 46s 473ms/step - loss: 0.6864 - lr: 0.0100
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6857WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 12s 476ms/step - loss: 0.6857 - lr: 0.0100
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 485ms/step - loss: 0.6852 - lr: 0.0100
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 488ms/step - loss: 0.6852 - lr: 0.0100
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6853WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 496ms/step - loss: 0.6853 - lr: 0.0100
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 487ms/step - loss: 0.6852 - lr: 0.0100
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6845WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 503ms/step - loss: 0.6845 - lr: 0.0100
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6847WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 507ms/step - loss: 0.6847 - lr: 0.0100
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6844WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 506ms/step - loss: 0.6844 - lr: 0.0100
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6829WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 501ms/step - loss: 0.6829 - lr: 0.0100
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6836WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 487ms/step - loss: 0.6836 - lr: 0.0090
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 493ms/step - loss: 0.6828 - lr: 0.0081
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6827WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 484ms/step - loss: 0.6827 - lr: 0.0073
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6829WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 487ms/step - loss: 0.6829 - lr: 0.0066
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6820WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 500ms/step - loss: 0.6820 - lr: 0.0059
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6822WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 489ms/step - loss: 0.6822 - lr: 0.0053
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6821WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 493ms/step - loss: 0.6821 - lr: 0.0048
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6818WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 491ms/step - loss: 0.6818 - lr: 0.0043
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6824WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 491ms/step - loss: 0.6824 - lr: 0.0039
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6820WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 500ms/step - loss: 0.6820 - lr: 0.0035
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 491ms/step - loss: 0.6812 - lr: 0.0031
# Epoch 22/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6813WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 488ms/step - loss: 0.6813 - lr: 0.0028
# Epoch 23/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6820WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 485ms/step - loss: 0.6820 - lr: 0.0025
# Epoch 24/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6810WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 491ms/step - loss: 0.6810 - lr: 0.0023
# Epoch 25/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6813WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 502ms/step - loss: 0.6813 - lr: 0.0021
# Epoch 26/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6802WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 490ms/step - loss: 0.6802 - lr: 0.0019
# Epoch 27/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 491ms/step - loss: 0.6812 - lr: 0.0017
# Epoch 28/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6807WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 485ms/step - loss: 0.6807 - lr: 0.0015
# Epoch 29/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6806WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 492ms/step - loss: 0.6806 - lr: 0.0014
# Epoch 30/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6809WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 489ms/step - loss: 0.6809 - lr: 0.0012
# Epoch 31/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6806WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 498ms/step - loss: 0.6806 - lr: 0.0011
# Epoch 32/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6808WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 485ms/step - loss: 0.6808 - lr: 9.8477e-04
# Epoch 33/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6804WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 12s 480ms/step - loss: 0.6804 - lr: 8.8629e-04
# Epoch 34/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6799WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 499ms/step - loss: 0.6799 - lr: 7.9766e-04
# Epoch 35/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6801WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 492ms/step - loss: 0.6801 - lr: 7.1790e-04
# Epoch 36/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6809WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 489ms/step - loss: 0.6809 - lr: 6.4611e-04
# Epoch 37/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6803WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 490ms/step - loss: 0.6803 - lr: 5.8150e-04
# Epoch 38/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6805WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 480ms/step - loss: 0.6805 - lr: 5.2335e-04
# Epoch 39/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 492ms/step - loss: 0.6812 - lr: 4.7101e-04
# Epoch 40/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6801WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 494ms/step - loss: 0.6801 - lr: 4.2391e-04
# Epoch 41/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6807WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 494ms/step - loss: 0.6807 - lr: 3.8152e-04
# Epoch 42/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6810WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 494ms/step - loss: 0.6810 - lr: 3.4337e-04
# Epoch 43/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6808WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 12s 479ms/step - loss: 0.6808 - lr: 3.0903e-04
# Epoch 44/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6800WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 492ms/step - loss: 0.6800 - lr: 2.7813e-04
# Epoch 45/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6811WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 503ms/step - loss: 0.6811 - lr: 2.5032e-04
# Epoch 46/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6808WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 491ms/step - loss: 0.6808 - lr: 2.2528e-04
# Epoch 47/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6810WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 482ms/step - loss: 0.6810 - lr: 2.0276e-04
# Epoch 48/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6807WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 486ms/step - loss: 0.6807 - lr: 1.8248e-04
# Epoch 49/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6804WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 496ms/step - loss: 0.6804 - lr: 1.6423e-04
# Epoch 50/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6806WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 496ms/step - loss: 0.6806 - lr: 1.4781e-04
# 13/13 [==============================] - 6s 63ms/step
# The root mean squared error is 1.1092825473039842.

# %% [markdown]
# **The results of the model**

# %%
#Initialise data of lists for error values of four junctions.
Junctions = ["Junction1", "Junction2", "Junction3", "Junction4"]
RMSE = [RMSE_J1, RMSE_J2, RMSE_J3, RMSE_J4]
list_of_tuples = list(zip(Junctions, RMSE))
# Creates pandas DataFrame.
Results = pd.DataFrame(list_of_tuples, columns=["Junction", "RMSE"])
Results.style.background_gradient(cmap="Pastel1")
# Out:
# <style type="text/css">
# #T_3077a_row0_col1 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_3077a_row1_col1, #T_3077a_row2_col1 {
#   background-color: #decbe4;
#   color: #000000;
# }
# #T_3077a_row3_col1 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# </style>
# <table id="T_3077a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3077a_level0_col0" class="col_heading level0 col0" >Junction</th>
#       <th id="T_3077a_level0_col1" class="col_heading level0 col1" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3077a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3077a_row0_col0" class="data row0 col0" >Junction1</td>
#       <td id="T_3077a_row0_col1" class="data row0 col1" >0.300151</td>
#     </tr>
#     <tr>
#       <th id="T_3077a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3077a_row1_col0" class="data row1 col0" >Junction2</td>
#       <td id="T_3077a_row1_col1" class="data row1 col1" >0.621130</td>
#     </tr>
#     <tr>
#       <th id="T_3077a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3077a_row2_col0" class="data row2 col0" >Junction3</td>
#       <td id="T_3077a_row2_col1" class="data row2 col1" >0.628103</td>
#     </tr>
#     <tr>
#       <th id="T_3077a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3077a_row3_col0" class="data row3 col0" >Junction4</td>
#       <td id="T_3077a_row3_col1" class="data row3 col1" >1.109283</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **The Root Mean Square Error is quite a subjective marker for evaluating the performance.
# Thus, in this project, I am including the outcome plots as well.**

# %% [markdown]
# # Inversing The Transformation Of Data

# %%
# Functions to inverse transforms and Plot comparitive plots
# invert differenced forecast
def inverse_difference(last_ob, value):
    inversed = value + last_ob
    return inversed
#Plotting the comparison
def Sub_Plots2(df_1, df_2,title,m):
    fig, axes = plt.subplots(1, 2, figsize=(18,4), sharey=True)#,facecolor="#627D78")
    fig.suptitle(title)
    
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[m])
    axes[0].set(ylabel ="Prediction")
    
    pl_2=sns.lineplot(ax=axes[1],data=df_2["Vehicles"],color="#627D78")
    axes[1].set(ylabel ="Original")

# %%
# invert the differenced forecast for Junction 1 
recover1 = df_N1.Norm[-1412:-1].to_frame()
recover1["Pred"]= PredJ1
Transform_reverssed_J1 = inverse_difference(recover1.Norm, recover1.Pred).to_frame()
Transform_reverssed_J1.columns = ["Pred_Normed"]
#Invert the normalizeation J1
Final_J1_Pred = (Transform_reverssed_J1.values* std_J1) + av_J1
Transform_reverssed_J1["Pred_Final"] =Final_J1_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J1["Pred_Final"], df_1[-1412:-1],"Predictions And Originals For Junction 1", 0)

# %%
# Saving the average and std for inverse transformation
# Saving for Junction 1
#np.save("junction_1_average.npy", av_J1)
#np.save("junction_1_std.npy", std_J1)

# %%
# Save the DataFrame to a CSV file (replace 'your_file_path.csv' with the desired path)
#Transform_reverssed_J1.to_csv('C:/Users/SONY/Downloads/Python/Transform_reverssed_J1.csv', index=False)

# %%
#Invert the differenced J2
recover2 = df_N2.Norm[-1426:-1].to_frame() #len as per the diff
recover2["Pred"]= PredJ2
Transform_reverssed_J2 = inverse_difference(recover2.Norm, recover2.Pred).to_frame()
Transform_reverssed_J2.columns = ["Pred_Normed"]
Final_J2_Pred = (Transform_reverssed_J2.values* std_J2) + av_J2
Transform_reverssed_J2["Pred_Final"] =Final_J2_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J2["Pred_Final"], df_2[-1426:-1],"Predictions And Originals For Junction 2", 1)

# %%
# Saving for Junction 2
#np.save("junction_2_average.npy", av_J2)
#np.save("junction_2_std.npy", std_J2)

# %%
# Save the DataFrame to a CSV file (replace 'your_file_path.csv' with the desired path)
#Transform_reverssed_J2.to_csv('C:/Users/SONY/Downloads/Python/Transform_reverssed_J2.csv', index=False)

# %%
#Invert the differenced J3
recover3 = df_N3.Norm[-1429:-1].to_frame() #len as per the diff
recover3["Pred"]= PredJ3
Transform_reverssed_J3 = inverse_difference(recover3.Norm, recover3.Pred).to_frame()
Transform_reverssed_J3.columns = ["Pred_Normed"]
#Invert the normalizeation J3
Final_J3_Pred = (Transform_reverssed_J3.values* std_J3) + av_J3
Transform_reverssed_J3["Pred_Final"] =Final_J3_Pred
Sub_Plots2(Transform_reverssed_J3["Pred_Final"], df_3[-1429:-1],"Predictions And Originals For Junction 3", 2)

# %%
# Saving for Junction 3
#np.save("junction_3_average.npy", av_J3)
#np.save("junction_3_std.npy", std_J3)

# %%
# Save the DataFrame to a CSV file (replace 'your_file_path.csv' with the desired path)
#Transform_reverssed_J3.to_csv('C:/Users/SONY/Downloads/Python/Transform_reverssed_J3.csv', index=False)

# %%
#Invert the differenced J4
recover4 = df_N4.Norm[-404:-1].to_frame()  #len as per the testset
recover4["Pred"]= PredJ4
Transform_reverssed_J4 = inverse_difference(recover4.Norm, recover4.Pred).to_frame()
Transform_reverssed_J4.columns = ["Pred_Normed"]
#Invert the normalizeation J4
Final_J4_Pred = (Transform_reverssed_J4.values* std_J4) + av_J4
Transform_reverssed_J4["Pred_Final"] =Final_J4_Pred
Sub_Plots2(Transform_reverssed_J4["Pred_Final"], df_4[-404:-1],"Predictions And Originals For Junction 4", 3)

# %%
# Saving for Junction 4
#np.save("junction_4_average.npy", av_J4)
#np.save("junction_4_std.npy", std_J4)

# %%
# Save the DataFrame to a CSV file (replace 'your_file_path.csv' with the desired path)
#Transform_reverssed_J4.to_csv('C:/Users/SONY/Downloads/Python/Transform_reverssed_J4.csv', index=False)

# %%
# Save the true test datasets for Junctions
#np.save("junction_1_test_y.npy", y_testJ1)
#np.save("junction_2_test_y.npy", y_testJ2)
#np.save("junction_3_test_y.npy", y_testJ3)
#np.save("junction_4_test_y.npy", y_testJ4)

# %% [markdown]
# **Summary**
#
# *In this project, I trained a GRU Neural network to predicted the traffic on four junctions.
# I used a normalisation and differencing transform to achieve a stationary timeseries. As the Junctions varry in trends and seasonality, I took diffrent approach for each junction to make it stationary. I applyied the root mean squred error as the evaluation metric for the model. In addition to that I plotted the Predictions alongside the original test values.
# Take aways from the data analysis:*
#
# *The Number of vehicles in Junction one is rising more rapidly compaired to junction two and three. The sparsity of data in juction four bars me from making any conclusion on the same.*
#
# *The Junction one's traffic has a stronger weekly seasonality as well as hourly seasonality. Where as other junctions are significantly linear.*
